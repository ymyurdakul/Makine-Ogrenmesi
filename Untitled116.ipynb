# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
ads=pd.read_csv("Advertising.csv")

# %%
ads=ads.drop("Unnamed: 0",axis=1)

# %%
x=ads.drop("sales",axis=1)

# %%
y=ads.sales

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
ads.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression 
lm=LinearRegression()
lm.fit(x_train,y_train)
y_pred=lm.predict(x_test)
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_pred,y_test))
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
cross_val_score(lm,x_train,y_train,cv=10,scoring="r2").mean()
r2_score(y_test,y_pred)
-cross_val_score(lm,x_train,y_train,cv=10,scoring="neg_mean_squared_error").mean()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lm.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_pred,y_test))
# Out:
# 1.7443533241224127

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(lm,x_train,y_train,cv=10,scoring="r2").mean()
# Out:
# 0.8945164031092141

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8558209769960856

# %%
-cross_val_score(lm,x_train,y_train,cv=10,scoring="neg_mean_squared_error").mean()
# Out:
# 2.9071652669830383

# %%
ads.sales.mean()
# Out:
# 14.022500000000003

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(ads,kind="reg")

# %%
from sklearn.linear_model import ElasticNet

# %%
en=ElasticNet().fit(x_train,y_train)

# %%
y_pred=en.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1.7496386282338434

# %%
from sklearn.linear_model import ElasticNetCV

# %%
en_cv=ElasticNetCV(cv=10,random_state=45).fit(x_train,y_train)

# %%
en_cv.alpha_
# Out:
# 2.35278027094759

# %%
en_tuned=ElasticNet(alpha=en_cv.alpha_).fit(x_train,y_train)

# %%
y_pred=en_tuned.predict(x_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1.7579545094708076

# %%
# Out:
# array([11.7,  1.6, 18. ,  8.7, 12.2, 17.3, 12. , 11.5, 11.5, 15.2])

# %%
pd.DataFrame(-np.round((y_test.values[0:1000]-y_pred[0:1000]),2)).plot()

# %%
ads.shape
# Out:
# (200, 4)

# %%
from sklearn.linear_model import Lasso

# %%
lm=Lasso()

# %%
lm.fit(x_train,y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_pred=lm.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1.7537150260764751

# %%
from sklearn.linear_model import LassoCV

# %%
lc=LassoCV(alphas=None,cv=10,max_iter=10000,normalize=True)

# %%
lc.fit(x_train,y_train)
# Out:
# LassoCV(alphas=None, copy_X=True, cv=10, eps=0.001, fit_intercept=True,
#         max_iter=10000, n_alphas=100, n_jobs=None, normalize=True,
#         positive=False, precompute='auto', random_state=None,
#         selection='cyclic', tol=0.0001, verbose=False)

# %%
lc.alpha_
# Out:
# 0.0070974833996314615

# %%
lc=Lasso(alpha=lc.alpha_)

# %%
lc.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.0070974833996314615, copy_X=True, fit_intercept=True,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_pred=lc.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1.7444049189565087

# %%
y_pred
# Out:
# array([12.71867998, 10.33850136, 16.90681384,  6.6406148 , 14.02694182,
#        16.43365482, 11.57663331, 10.51654019, 13.83739612, 15.26104061,
#        12.1346754 ,  6.85002217, 17.28039451, 10.07415084, 16.84055646,
#        16.40548908, 20.61536747, 14.00329319, 21.23102652, 14.98553502,
#        18.44418107,  9.90715115, 19.89437181,  6.69128615, 14.39250658,
#         9.79703012, 14.04751944,  9.75518143, 15.56647817,  7.95671386,
#        12.29168101, 18.57347689,  7.44277734, 17.06129348, 16.32083068,
#        16.85104315, 12.86310191, 17.23647426, 20.41060158, 12.84222819,
#        13.53622553, 20.88558121, 14.96175122,  9.51007346, 20.36261453,
#        18.43090775, 16.36489393, 23.18848692, 13.90592182, 14.87740183])

# %%
ads[["TV","radio","sales"]].plot()
