# %%
from scipy.stats import binom
# Out:
# C:\Users\Mustafa\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Mustafa\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
dx=binom.rvs(n=2,p=0.5,size=10)

# %%
import seaborn as sns

# %%
sns.distplot(dx)
dx
# Out:
# array([1, 1, 2, 0, 1, 1, 2, 1, 1, 2])

# %%
a=bin

# %%
import scipy.stats as stats

# %%
f=stats.binom(n=100,p=0.5)

# %%
tx=f.pmf([i for i in range(40)])
import matplotlib.pyplot as plt

# %%
import numpy as np
bd1=stats.binom(20,0.5)
bd2=stats.binom(20,0.7)
bd3=stats.binom(40,0.5)
k=np.arange(40)

# %%
plt.plot(k,bd1.pmf(k))
plt.plot(k,bd2.pmf(k))
plt.plot(k,bd3.pmf(k))

# %%
zar=stats.binom(100,0.6)

# %%
zar.pmf(6)
# Out:
# 2.1819361294284227e-30
