# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

def pscore(sutun):
    return sutun["Family"]*sutun["Freedom"]**sutun["Happiness.Rank"]

x=pd.read_csv("wh_2017.csv")
f=x.apply(pscore,axis=1)
x["F Score"]=f
x.head(2)
x.loc[[0,100,154],["Country"]]
# Out:
#                       Country
# 0                      Norway
# 100              South Africa
# 154  Central African Republic

# %%
x.iloc[0:2,0:2]
x.iloc[[0,2],2:8]
# Out:
#    Happiness.Score  Whisker.high  Whisker.low  Economy..GDP.per.Capita.  \
# 0            7.537      7.594445     7.479556                  1.616463
# 2            7.504      7.622030     7.385970                  1.480633
#
#      Family  Health..Life.Expectancy.
# 0  1.533524                  0.796667
# 2  1.610574                  0.833552

# %%
filtre1=x["Happiness.Rank"]<7
x[filtre1].head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
# ...

# %%
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
# 2  Iceland               3            7.504      7.622030     7.385970
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual   F Score
# 0    0.362012                       0.315964           2.277027  0.974436
# 1    0.355280                       0.400770           2.313707  0.607860
# 2    0.475540                       0.153527           2.322715  0.397302

# %%
for index,row in x.iterrows():
    #print(row["Country"])
    pass
for index,col in x.iteritems():
    #print(col)
    pass
x.index.name="sira"
x.head()

k=pd.DataFrame([[1,2,3],[7,8,9],[10,21,5]],columns=["Ankara","Yozgat","Bolu"])
k.index=["a","b","c"]
k.index.name="sira"

# %%
x.head()
# Out:
#              Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# sira
# Norway                    1            7.537      7.594445     7.479556
# Denmark                   2            7.522      7.581728     7.462272
# Iceland                   3            7.504      7.622030     7.385970
# Switzerland               4            7.494      7.561772     7.426227
# Finland                   5            7.469      7.527542     7.410458
#
#              Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# sira
# Norway                       1.616463  1.533524                  0.796667
# Denmark                      1.482383  1.551122                  0.792566
# Iceland                      1.480633  1.610574                  0.833552
# Switzerland                  1.564980  1.516912                  0.858131
# Finland                      1.443572  1.540247                  0.809158
#
#               Freedom  Generosity  Trust..Government.Corruption.  \
# ...

# %%
x.reindex(columns=["er","Country","Country","Country","Country","Country","Country","Country","Country","Country","Country","Country"])
# Out:
#                           er  Country  Country  Country  Country  Country  \
# sira
# Norway                   NaN      NaN      NaN      NaN      NaN      NaN
# Denmark                  NaN      NaN      NaN      NaN      NaN      NaN
# Iceland                  NaN      NaN      NaN      NaN      NaN      NaN
# Switzerland              NaN      NaN      NaN      NaN      NaN      NaN
# Finland                  NaN      NaN      NaN      NaN      NaN      NaN
# Netherlands              NaN      NaN      NaN      NaN      NaN      NaN
# Canada                   NaN      NaN      NaN      NaN      NaN      NaN
# New Zealand              NaN      NaN      NaN      NaN      NaN      NaN
# Sweden                   NaN      NaN      NaN      NaN      NaN      NaN
# Australia                NaN      NaN      NaN      NaN      NaN      NaN
# Israel                   NaN      NaN      NaN      NaN      NaN      NaN
# Costa Rica               NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
x=pd.read_csv("wh_2015.csv")
x.tail()
x.reindex(columns=["er","Country","Country","Country","Country","Country","Country","Country","Country","Country","Country","Country"])
# Out:
#      er                   Country                   Country  \
# 0   NaN               Switzerland               Switzerland
# 1   NaN                   Iceland                   Iceland
# 2   NaN                   Denmark                   Denmark
# 3   NaN                    Norway                    Norway
# 4   NaN                    Canada                    Canada
# 5   NaN                   Finland                   Finland
# 6   NaN               Netherlands               Netherlands
# 7   NaN                    Sweden                    Sweden
# 8   NaN               New Zealand               New Zealand
# 9   NaN                 Australia                 Australia
# 10  NaN                    Israel                    Israel
# 11  NaN                Costa Rica                Costa Rica
# 12  NaN                   Austria                   Austria
# 13  NaN                    Mexico                    Mexico
# 14  NaN             United States             United States
# ...

# %%
x=pd.read_csv("import.csv")
x=x.fillna(0)
x.describe()
x[x["country"]=="TURKEY"]["value"]

# %%
x[x["country"]=="TURKEY"]["value"]
