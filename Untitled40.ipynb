# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
wh_2017=pd.read_csv("wh_2017.csv")
wh_2017.head()
wh=wh_2017
wh.index=np.arange(len(wh))**2

# %%
d=pd.DataFrame(columns=["isim","soyisim"],data=[["ali","veli"],["mahmut","kaya"]],index=["i","ii"])
#d.index=["a","b"]
d.reindex(index="isim")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-4c575ce5a35d> in <module>
#       1 d=pd.DataFrame(columns=["isim","soyisim"],data=[["ali","veli"],["mahmut","kaya"]],index=["i","ii"])
#       2 #d.index=["a","b"]
# ----> 3 d.reindex(index="isim")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3807         kwargs.pop('axis', None)
#    3808         kwargs.pop('labels', None)
# -> 3809         return super(DataFrame, self).reindex(**kwargs)
#    3810
#    3811     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ...

# %%
ulke=pd.DataFrame(data=[["Türkiye",82],["Çin",500],["Almanya",90]],columns=["Ülke ismi","Nufus"])
ulke
ulke_yuzolcumu=pd.DataFrame(data=[["Türkiye",855],["Çin",154],["Almanya",140]],columns=["Ülke ismi","Yuz Olcum"])
pd.concat([ulke,ulke_yuzolcumu],axis=1,sort=False)
# Out:
#   Ülke ismi  Nufus Ülke ismi  Yuz Olcum
# 0   Türkiye     82   Türkiye        855
# 1       Çin    500       Çin        154
# 2   Almanya     90   Almanya        140

# %%
personel=pd.DataFrame(data=[["Ali","Yayla",25],["Mustafa","Yurdakul",22],["Ahmet","Kaya",25]],columns=["Ad","Soyad","Yas"])
personel
personel_özel=pd.DataFrame(columns=["Ad","İzin","Maas"],data=[["Mustafa","50","5800"],["Ali","20","2000"]])
a=pd.concat([personel,personel_özel],axis=1,join="outer")
a.set_index("Ad")
# Out:
#                    Soyad  Yas İzin  Maas
# Ad
# (Ali, Mustafa)     Yayla   25   50  5800
# (Mustafa, Ali)  Yurdakul   22   20  2000
# (Ahmet, nan)        Kaya   25  NaN   NaN

# %%
wh.loc["Turkey"]
wh["Region"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-65fe16547c17> in <module>
#       1 wh.loc["Turkey"]
# ----> 2 wh["Region"]
#
# ...

# %%
wh.loc[["Norway","Turkey","France","Iraq","United States","Germany"],["Family","Freedom","Happiness.Score"]].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001AFEAF2DB00>,
# ...
#       dtype=object)

# %%
wh_2017.rename(columns=["Ulke","Bolge","ds"],)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-b5daf4646f58> in <module>
# ----> 1 wh_2017.rename(columns=["Ulke","Bolge","ds"],)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    4023         kwargs.pop('axis', None)
#    4024         kwargs.pop('mapper', None)
# -> 4025         return super(DataFrame, self).rename(**kwargs)
#    4026
#    4027     @Substitution(**_shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, *args, **kwargs)
#    1089                 level = self.axes[axis]._get_level_number(level)
# ...

# %%
wh_2017.rename(columns = {"NEW NAME": "Mutluluk Sıralaması", 
                     "Happiness.Score":"Skorrr"}, 
                                 inplace = True) 
wh_2017
# Out:
#                           Mutluluk Sıralaması  Skorrr  Whisker.high  \
# Country
# Norway                                      1   7.537      7.594445
# Denmark                                     2   7.522      7.581728
# Iceland                                     3   7.504      7.622030
# Switzerland                                 4   7.494      7.561772
# Finland                                     5   7.469      7.527542
# Netherlands                                 6   7.377      7.427426
# Canada                                      7   7.316      7.384403
# New Zealand                                 8   7.314      7.379510
# Sweden                                      9   7.284      7.344095
# Australia                                  10   7.284      7.356651
# Israel                                     11   7.213      7.279853
# Costa Rica                                 12   7.079      7.168112
# Austria                                    13   7.006      7.070670
# ...

# %%
ulke=pd.DataFrame(columns=["Ad","Nufus"],data=[["Almanya",1545],["İtalya",7955],["Türkiye",82]])
ulke
ulke_yo=pd.DataFrame(columns=["Ad","YuzOlcumu"],data=[["Almanya",12],["İtalya",52],["Fransa",85],["Türkiye",899]])
ulke.join(ulke_yo,lsuffix="_l",rsuffix="_r")
# Out:
#       Ad_l  Nufus     Ad_r  YuzOlcumu
# 0  Almanya   1545  Almanya         12
# 1   İtalya   7955   İtalya         52
# 2  Türkiye     82   Fransa         85

# %%
sutunlar=[["bir","bir","iki","iki","uc","uc"],[1.1,1.2,2.1,2.2,3.1,3.2]]
f=pd.DataFrame(np.random.randn(6,6),index=sutunlar)
f
# Out:
#                 0         1         2         3         4         5
# bir 1.1  0.804102  0.752219 -0.363372 -0.542877  1.117982 -0.051081
#     1.2  0.133003 -0.573173  0.610584  0.761756 -0.245929  0.361654
# iki 2.1 -1.284707 -0.410347  0.306933  0.552327  1.104286  0.932312
#     2.2  0.755494  1.326981  0.189903  0.052605 -2.310435 -0.166401
# uc  3.1 -1.783051  0.505943 -1.008496 -0.307811 -1.157952 -1.047587
#     3.2 -1.143454 -0.121217 -1.003929 -0.262766  0.075956 -1.561935

# %%
table=pd.DataFrame(data=[["Ali","A","120"],["Ali","B","300"],["Mehmet","A","120"],["Mehmet","B","2000"]],
                  columns=["Ad","Okul","Mesafe"])
table.pivot(index="Okul",columns="Ad",values="Mesafe")
# Out:
# Ad    Ali Mehmet
# Okul
# A     120    120
# B     300   2000

# %%
table.set_index(["Ad","Okul"])
table.unstack(level="Okul")
# Out:
# Ad      0       Ali
#         1       Ali
#         2    Mehmet
#         3    Mehmet
# Okul    0         A
#         1         B
#         2         A
#         3         B
# Mesafe  0       120
#         1       300
#         2       120
#         3      2000
# dtype: object
