# %%
import pandas as pd
import numpy as np
import seaborn as sns
 
x=[1,2,3,4,5,6]
y=[1,2,3,4,5,6]

xx,yy=np.meshgrid(x,y)
z=xx*yy
sns.heatmap(z,annot=True,xticklabels=str("123456"),yticklabels=str("123456"))
l=sns.load_dataset("attention")
f=l.pivot_table(columns="solutions")
sns.heatmap(f,annot=True)

# %%
iris=sns.load_dataset("iris")
iris
plt.subplot(2,2,1)
sns.lmplot(x="sepal_length",y="sepal_width",data=iris)
plt.subplot(2,2,2)
sns.lmplot(x="petal_length",y="sepal_width",data=iris)
