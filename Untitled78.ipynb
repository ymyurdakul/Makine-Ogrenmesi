# %%
from scipy.stats import poisson
import scipy.stats as stats
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Mustafa\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Mustafa\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# C:\Users\Mustafa\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data=poisson.rvs(mu=100,size=6000)

# %%
sns.distplot(data)

# %%
import numpy as np
k=np.arange(7)
ps=stats.poisson(6)
plt.plot(k,ps.pmf(k))

# %%
import pandas as pd

# %%
df=pd.read_csv("eq.csv")

# %%
turkey = df[df["country"] == "turkey"]

# %%
turkey
# Out:
#                   datetime    lat   long country            city  \
# 3      1911-04-30 12:42:03  36.00  30.00  turkey         antalya
# 13     1912-08-09 12:29:00  40.60  27.20  turkey        tekirdag
# 15     1912-08-10 12:23:00  40.60  27.10  turkey        tekirdag
# 16     1912-08-10 12:30:00  40.60  27.10  turkey        tekirdag
# 17     1912-08-11 12:19:04  40.60  27.20  turkey        tekirdag
# 18     1912-08-11 12:20:00  40.60  27.10  turkey        tekirdag
# 19     1912-09-16 12:04:02  40.10  26.80  turkey       canakkale
# 22     1912-10-21 12:31:00  40.50  27.00  turkey  marmara_denizi
# 23     1912-10-21 12:40:00  40.50  27.00  turkey  marmara_denizi
# 25     1913-01-27 12:38:36  38.38  42.23  turkey          bitlis
# 37     1914-02-08 12:00:01  37.80  27.00  turkey           aydin
# 40     1914-03-22 12:57:03  40.00  26.00  turkey       canakkale
# 41     1914-05-28 12:27:30  39.84  35.80  turkey          yozgat
# ...

# %%
al=len(turkey)
a=len(turkey[turkey["richter"]>5.0])
prob=a/al
prob
ts=pd.to_datetime(turkey["datetime"].max())-pd.to_datetime(turkey["datetime"].min())

# %%
ts.days
lambda x:prob**5*np.e**(-prob)/np.fa
# Out:
# 38809
