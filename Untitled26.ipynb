# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib notebook
a=np.arange(10)
plt.scatter(a,a**2,marker="*",color="r")
plt.figure(figsize=[5,5])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
