# %% [markdown]
# # Simple Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,np.pi*2,0.05)
y=np.sin(x)
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y");
plt.title("Sin Plot")
# Out:
# Text(0.5, 1.0, 'Sin Plot')

# %%
fig=plt.figure()
