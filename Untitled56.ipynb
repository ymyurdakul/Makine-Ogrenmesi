# %%
import seaborn as sns
import numpy as np
cc=sns.load_dataset("car_crashes")
cx=cc.groupby("abbrev").mean()
sns.heatmap(cx,cmap="hot")
cc.groupby("abbrev").aggregate(["min",np.median,"max"])
#sns.get_dataset_names()
ex=sns.load_dataset("exercise")
ex.groupby("kind").aggregate(["min","max","mean"])
# Out:
#         Unnamed: 0            id           pulse
#                min max  mean min max  mean   min  max        mean
# kind
# rest             0  29  14.5   1  10   5.5    80  100   90.833333
# walking         30  59  44.5  11  20  15.5    84  109   95.200000
# running         60  89  74.5  21  30  25.5    87  150  113.066667

# %%
ex.groupby(by="kind").filter(lambda x:x["id"].sum()>5)
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# 5            5   2  low fat     93  30 min     rest
# 6            6   3  low fat     97   1 min     rest
# 7            7   3  low fat     97  15 min     rest
# 8            8   3  low fat     94  30 min     rest
# 9            9   4  low fat     80   1 min     rest
# 10          10   4  low fat     82  15 min     rest
# 11          11   4  low fat     83  30 min     rest
# 12          12   5  low fat     91   1 min     rest
# 13          13   5  low fat     92  15 min     rest
# 14          14   5  low fat     91  30 min     rest
# 15          15   6   no fat     83   1 min     rest
# 16          16   6   no fat     83  15 min     rest
# ...

# %%
ex=ex.astype(str)
#ex.groupby(str.upper).mean()
#ex.info()
import pandas as pd
m=pd.Series(["Ali-Yayla","Veli-Hırsız","Kırk-Ayak","Dokuz-Doguran","Elli-bir"])
m=m.str.upper()
m[m.str.startswith("A")]
hg=m.str.split(pat="-",expand=True)
hg.rename(columns={"0":"Name","1":"Sname"},inplace=True)
# Out:
#        0        1
# 0    ALI    YAYLA
# 1   VELI   HIRSIZ
# 2   KIRK     AYAK
# 3  DOKUZ  DOGURAN
# 4   ELLI      BIR

# %%
with open('rc.json', 'r') as f:
 # Extract each line
 data = (line.strip() for line in f)
 # Reformat so each line is the element of a list
 data_json = "[{0}]".format(','.join(data))
 # read the result as a JSON
 recipes = pd.read_json(data_json)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-108-55bf8541cd0d> in <module>
#       3  data = (line.strip() for line in f)
#       4  # Reformat so each line is the element of a list
# ----> 5  data_json = "[{0}]".format(','.join(data))
#       6  # read the result as a JSON
#       7  recipes = pd.read_json(data_json)
#
# <ipython-input-108-55bf8541cd0d> in <genexpr>(.0)
#       1 with open('rc.json', 'r') as f:
#       2  # Extract each line
# ----> 3  data = (line.strip() for line in f)
#       4  # Reformat so each line is the element of a list
#       5  data_json = "[{0}]".format(','.join(data))
#
# ~\Anaconda3\lib\encodings\cp1254.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ...

# %%
from IPython.display import Image
import matplotlib.pyplot as plt
fig=plt.figure()
#plt.scatter(np.random.randint(0,100,100),np.random.randint(0,100,100))
fig.savefig("scasyon.png")
#Image("scasyon.png")
plt.style.use('seaborn-whitegrid')
#fig,ax=plt.subplots(ncols=2)
#ax[0].plot(np.random.randint(0,100,100),np.arange(100),linestyle="--")
#ax[1].scatter(np.random.randint(0,100,100),np.random.randint(0,100,100),color="r")
x=np.arange(10)
y=x**2
plt.plot(x,y,linestyle="--",c="r",marker="*",label="kırmızı")
plt.plot(x+10,y+10,linestyle=":",c="g",marker="s",label="green")
plt.legend(["alfa","beta"])
plt.xlim(0,20)
plt.ylim(0,20)
# Out:
# (0, 20)
