# %%
class Gen:
    val=0
    def __init__(self,val):
        self.val=val
    def __str__(self):
        return  str(self.val)
class Kromozom:
    genler=[]
    fitness=0
    def addGen(self,gen):
        self.genler.append(gen)
    def calcFitness(self):
        self.fitness=Function.calc(self.genler)
    def __str__(self):
        s=""
        for v in self.genler:
            s+=str(v)
        return s
class Function:
    @staticmethod
    def calc(genler):
        toplam=0
        for gen in genler:
            toplam+=gen.val
        return toplam
class Population:
    kromozomlar=[]
    def addKromozom(self,kro):
        self.kromozomlar.append(kro)
    def initialize(self):
        for i in range(10):

# %%
k1=Kromozom()
for i in range(10):
    import random as rnd
    if(rnd.randint(1,100)%2==0):
        k1.addGen(Gen(0))
    else:
        k1.addGen(Gen(1))
k1.__str__()
k1.calcFitness()
k1.fitness

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(10)
y=np.power(x,2)
plt.plot(x,y,"--og")
plt.title("X in y e göre karesi")
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")
plt.plot(x,np.add(y,10),"r+-",linewidth=5) 
plt.legend(["a","b"])
plt.grid()
plt.show()
